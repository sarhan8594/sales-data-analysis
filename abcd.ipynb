# %%
print("jupiter")
# Out:
# jupiter

# %%
# !pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      - -------------------------------------- 0.3/10.7 MB 8.3 MB/s eta 0:00:02
#      --- ------------------------------------ 0.8/10.7 MB 10.4 MB/s eta 0:00:01
#      ----- ---------------------------------- 1.4/10.7 MB 10.8 MB/s eta 0:00:01
#      ------- -------------------------------- 1.9/10.7 MB 11.0 MB/s eta 0:00:01
#      --------- ------------------------------ 2.5/10.7 MB 11.2 MB/s eta 0:00:01
#      ----------- ---------------------------- 3.0/10.7 MB 12.0 MB/s eta 0:00:01
#      ------------- -------------------------- 3.5/10.7 MB 11.9 MB/s eta 0:00:01
#      --------------- ------------------------ 4.1/10.7 MB 11.9 MB/s eta 0:00:01
#      ----------------- ---------------------- 4.7/10.7 MB 11.9 MB/s eta 0:00:01
#      ------------------- -------------------- 5.2/10.7 MB 11.8 MB/s eta 0:00:01
#      --------------------- ------------------ 5.7/10.7 MB 11.8 MB/s eta 0:00:01
# ...

# %%
# !pip install mathpoltlib
# Out:
# ERROR: Could not find a version that satisfies the requirement mathpoltlib (from versions: none)
# ERROR: No matching distribution found for mathpoltlib
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\user\Desktop\data analysis\abcd.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/data%20analysis/abcd.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/data%20analysis/abcd.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#      -- ------------------------------------- 0.4/7.6 MB 12.6 MB/s eta 0:00:01
#      ---- ----------------------------------- 0.9/7.6 MB 11.9 MB/s eta 0:00:01
#      ------- -------------------------------- 1.5/7.6 MB 11.7 MB/s eta 0:00:01
#      ---------- ----------------------------- 2.0/7.6 MB 11.8 MB/s eta 0:00:01
#      ------------- -------------------------- 2.6/7.6 MB 11.8 MB/s eta 0:00:01
#      ---------------- ----------------------- 3.2/7.6 MB 11.9 MB/s eta 0:00:01
#      ------------------- -------------------- 3.7/7.6 MB 11.8 MB/s eta 0:00:01
#      ---------------------- ----------------- 4.3/7.6 MB 11.8 MB/s eta 0:00:01
#      ------------------------- -------------- 4.8/7.6 MB 11.9 MB/s eta 0:00:01
#      ---------------------------- ----------- 5.4/7.6 MB 11.8 MB/s eta 0:00:01
#      ------------------------------ --------- 5.9/7.6 MB 11.8 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('superstore_sales.csv', encoding='utf-8')

# %%
profit_by_category_subcategory = df.groupby(['category', 'sub_category'])['profit'].sum()

# %%
print(profit_by_category_subcategory)
# Out:
# category                                                                                       sub_category
# "While you Were Out" Message Book                                                              Paper            10.3880
# #10 Gummed Flap White Envelopes                                                                Envelopes        16.7678
# #10 Self-Seal White Envelopes                                                                  Envelopes        52.1230
# #10 White Business Envelopes                                                                   Envelopes       223.1408
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                                                        Envelopes       115.2806
#                                                                                                                  ...
# iKross Bluetooth Portable Keyboard + Cell Phone Stand Holder + Brush for Apple iPhone 5S 5C 5  Phones          115.6440
# ...

# %%
pip install seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#      -------------------------------------- 294.6/294.6 kB 9.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
df = pd.read_csv('superstore_sales.csv')

# %%
# Create a figure and three subplots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

# Plot Category vs Sub-Category
axes[0].bar(df['Category'], df['Sub-Category'], color='skyblue')
axes[0].set_xlabel('Category')
axes[0].set_ylabel('Sub-Category')
axes[0].set_title('Category vs Sub-Category')

# Plot Sub-Category vs Profit
axes[1].bar(df['Sub-Category'], df['Profit'], color='green')
axes[1].set_xlabel('Sub-Category')
axes[1].set_ylabel('Profit')
axes[1].set_title('Sub-Category vs Profit')

# Bar chart for profit
axes[2].bar(df['Sub-Category'], df['Profit'], color='orange')
axes[2].set_xlabel('Sub-Category')
axes[2].set_ylabel('Profit')
axes[2].set_title('Sub-Category vs Profit')

# Rotate x-axis labels for better visibility
for ax in axes:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# Adjust layout and display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4304\3289798545.py:24: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# C:\Users\user\AppData\Local\Temp\ipykernel_4304\3289798545.py:24: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# C:\Users\user\AppData\Local\Temp\ipykernel_4304\3289798545.py:24: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %%
# Group the data by 'State' and calculate the total profit for each state
profit_by_state = df.groupby('State')['Profit'].sum().reset_index()

# Sort the data by profit in descending order
profit_by_state = profit_by_state.sort_values(by='Profit', ascending=False)

# Create a bar chart for profit by state
plt.figure(figsize=(12, 6))
plt.bar(profit_by_state['State'], profit_by_state['Profit'], color='skyblue')
plt.xlabel('State')
plt.ylabel('Total Profit')
plt.title('Total Profit by State')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import plotly.express as px

# %%
import plotly.offline as pyo

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file
df = pd.read_csv('superstore_sales.csv')

# Group the data by 'State' and calculate the total profit for each state
profit_by_state = df.groupby('State')['Profit'].sum().reset_index()

# Create a bar chart for profit by states
plt.figure(figsize=(12, 6))
plt.bar(profit_by_state['State'], profit_by_state['Profit'], color='skyblue')
plt.xlabel('State')
plt.ylabel('Total Profit')
plt.title('Total Profit by State')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Extract year from the 'Order Date' column
df['Year'] = pd.to_datetime(df['Order Date']).dt.year

# Group the data by 'Year' and calculate the total profit for each year
profit_by_year = df.groupby('Year')['Profit'].sum().reset_index()

# Create a bar chart with years on the x-axis and profit values on the y-axis
plt.figure(figsize=(10, 6))
plt.bar(profit_by_year['Year'], profit_by_year['Profit'], color='skyblue')
plt.xlabel('Year')
plt.ylabel('Total Profit')
plt.title('Total Profit by Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Group the data by 'Category' and calculate the total profit for each category
profit_by_category = df.groupby('Category')['Profit'].sum().reset_index()

# Create a bar chart with categories on the x-axis and profit values on the y-axis
plt.figure(figsize=(10, 6))
plt.bar(profit_by_category['Category'], profit_by_category['Profit'], color='skyblue')
plt.xlabel('Category')
plt.ylabel('Total Profit')
plt.title('Total Profit by Category')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Group the data by 'Sub-Category' and calculate the total profit for each sub-category
profit_by_subcategory = df.groupby('Sub-Category')['Profit'].sum().reset_index()

# Define colors for bars: orange for loss (negative profit) and green for profit (positive profit)
colors = ['orange' if profit < 0 else 'green' for profit in profit_by_subcategory['Profit']]

# Create a bar chart with sub-categories on the x-axis, profit values on the y-axis, and colored bars
plt.figure(figsize=(12, 6))
bars = plt.bar(profit_by_subcategory['Sub-Category'], profit_by_subcategory['Profit'], color=colors)
plt.xlabel('Sub-Category')
plt.ylabel('Total Profit')
plt.title('Profit by Sub-Category (Orange for Loss, Green for Profit)')
plt.xticks(rotation=90)
plt.tight_layout()

# Add data labels on the bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:,}', ha='center', va='bottom')

# Show the plot
plt.show()

# %%
# Group the data by 'State' and calculate the total profit for each state
profit_by_state = df.groupby('State')['Profit'].sum().reset_index()

# Define a custom colormap from orange to green (switched colors)
colors = [(0, '#FFA500'), (1, '#00FF00')]  # Orange to Green
cmap_name = 'orange_to_green'
cm = LinearSegmentedColormap.from_list(cmap_name, colors, N=256)

# Create a bar chart with state names on the y-axis and profit values on the x-axis
plt.figure(figsize=(10, 12))
bars = plt.barh(profit_by_state['State'], profit_by_state['Profit'], color=cm(profit_by_state['Profit'] / profit_by_state['Profit'].max()))
plt.ylabel('State')
plt.xlabel('Total Profit')
plt.title('Total Profit by State')

# Add color bar legend
sm = plt.cm.ScalarMappable(cmap=cm, norm=plt.Normalize(vmin=profit_by_state['Profit'].min(), vmax=profit_by_state['Profit'].max()))
sm.set_array([])  # Remove the data array for the color bar
cbar = plt.colorbar(sm, pad=0.02)
cbar.set_label('Profit')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\user\Desktop\data analysis\abcd.ipynb Cell 35 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/data%20analysis/abcd.ipynb#X46sZmlsZQ%3D%3D?line=23'>24</a> sm = plt.cm.ScalarMappable(cmap=cm, norm=plt.Normalize(vmin=profit_by_state['Profit'].min(), vmax=profit_by_state['Profit'].max()))
#      <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/data%20analysis/abcd.ipynb#X46sZmlsZQ%3D%3D?line=24'>25</a> sm.set_array([])  # Remove the data array for the color bar
# ---> <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/data%20analysis/abcd.ipynb#X46sZmlsZQ%3D%3D?line=25'>26</a> cbar = plt.colorbar(sm, pad=0.02)
#      <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/data%20analysis/abcd.ipynb#X46sZmlsZQ%3D%3D?line=26'>27</a> cbar.set_label('Profit')
# ...

# %%
import pandas as pd
import plotly.express as px

# Load the data from the CSV file
df = pd.read_csv('superstore_sales.csv')

# Group the data by 'State' and calculate the total profit for each state
profit_by_state = df.groupby('State')['Profit'].sum().reset_index()

# Create a choropleth map for profit by state
fig = px.choropleth(profit_by_state,
                    locations='State',
                    locationmode='INDIA',
                    color='Profit',
                    color_continuous_scale='YlOrRd',
                    range_color=(0, profit_by_state['Profit'].max()),  # Set the color scale range
                    labels={'Profit': 'Total Profit'},
                    title='Total Profit by State',
                    hover_data=['State', 'Profit'])  # Include additional data in hover tooltip

# Customize the map layout
fig.update_geos(showcoastlines=True, coastlinecolor="Black", showland=True, landcolor="White",
                showocean=True, oceancolor="#e6f2ff", showlakes=True, lakecolor="White")

# Show the map
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\user\Desktop\data analysis\abcd.ipynb Cell 36 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/data%20analysis/abcd.ipynb#X52sZmlsZQ%3D%3D?line=7'>8</a> profit_by_state = df.groupby('State')['Profit'].sum().reset_index()
#      <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/data%20analysis/abcd.ipynb#X52sZmlsZQ%3D%3D?line=9'>10</a> # Create a choropleth map for profit by state
# ---> <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/data%20analysis/abcd.ipynb#X52sZmlsZQ%3D%3D?line=10'>11</a> fig = px.choropleth(profit_by_state,
#      <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/data%20analysis/abcd.ipynb#X52sZmlsZQ%3D%3D?line=11'>12</a>                     locations='State',
# ...

# %%
import pandas as pd

# Load the data from the CSV file
df = pd.read_csv('superstore_sales.csv')

# Group the data by 'Product Name' and calculate the total sales for each product
total_sales_by_product = df.groupby('Product Name')['Sales'].sum().reset_index()

# Sort the products by total sales in descending order
sorted_products = total_sales_by_product.sort_values(by='Sales', ascending=False)

# Print the product with the highest total sales
most_sold_product = sorted_products.iloc[0]
print(f"The product that sells the most is '{most_sold_product['Product Name']}' with total sales of ${most_sold_product['Sales']:.2f}")
# Out:
# The product that sells the most is 'Canon imageCLASS 2200 Advanced Copier' with total sales of $61599.82

# %%
import pandas as pd

# Load the data from the CSV file
df = pd.read_csv('superstore_sales.csv')

# Group the data by 'Product Name' and calculate the total sales for each product
total_sales_by_product = df.groupby('Product Name')['Sales'].sum().reset_index()

# Find the product with the highest total sales
most_sold_product = total_sales_by_product.loc[total_sales_by_product['Sales'].idxmax()]

print(f"The product that is sold the most is '{most_sold_product['Product Name']}' with total sales of ${most_sold_product['Sales']:.2f}")
# Out:
# The product that is sold the most is 'Canon imageCLASS 2200 Advanced Copier' with total sales of $61599.82

# %%
import pandas as pd

# Load the data from the CSV file
df = pd.read_csv('superstore_sales.csv')

# Filter rows where the category is 'Technology'
technology_sales = df[df['Category'] == 'Technology']

# Extract year from the 'Order Date' column and create a new 'Year' column
technology_sales['Year'] = pd.to_datetime(technology_sales['Order Date']).dt.year

# Group technology sales by year and calculate total sales for each year
yearly_technology_sales = technology_sales.groupby('Year')['Sales'].sum()

print("Yearly total sales of technology items:")
print(yearly_technology_sales)
# Out:
# Yearly total sales of technology items:
# Year
# 2014    175278.233
# 2015    162780.809
# 2016    226364.180
# 2017    271730.811
# Name: Sales, dtype: float64
# C:\Users\user\AppData\Local\Temp\ipykernel_10604\1466786155.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   technology_sales['Year'] = pd.to_datetime(technology_sales['Order Date']).dt.year

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file
df = pd.read_csv('superstore_sales.csv')

# Filter rows where the category is 'Technology'
technology_sales = df[df['Category'] == 'Technology']

# Extract year from the 'Order Date' column and create a new 'Year' column
technology_sales['Year'] = pd.to_datetime(technology_sales['Order Date']).dt.year

# Group technology sales by year and calculate total sales for each year
yearly_technology_sales = technology_sales.groupby('Year')['Sales'].sum()

# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(yearly_technology_sales.index, yearly_technology_sales.values, color='skyblue')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.title('Year-wise Technology Items Sales')
plt.xticks(yearly_technology_sales.index)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10604\4242615819.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   technology_sales['Year'] = pd.to_datetime(technology_sales['Order Date']).dt.year

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Load the data from the CSV file
df = pd.read_csv('superstore_sales.csv')

# Select relevant features for segmentation
features = df[['Sales', 'Quantity', 'Discount', 'Profit']]

# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Perform K-means clustering (for example, with 3 clusters)
num_clusters = 3
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df['Cluster'] = kmeans.fit_predict(scaled_features)

# Analyze the segments
segment_analysis = df.groupby('Cluster').agg({
    'Sales': 'mean',
    'Quantity': 'mean',
    'Discount': 'mean',
    'Profit': 'mean',
    'Customer ID': 'count'
})

print(segment_analysis)
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#               Sales  Quantity  Discount      Profit  Customer ID
# Cluster
# 0        122.810078  2.835143  0.095300   20.658453         6909
# 1        158.884796  3.822097  0.661938 -106.792498         1068
# 2        634.118527  7.041646  0.097030  127.774992         2017

# %%
pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#      -- ------------------------------------- 0.5/9.3 MB 10.2 MB/s eta 0:00:01
#      ---- ----------------------------------- 1.0/9.3 MB 11.1 MB/s eta 0:00:01
#      ------ --------------------------------- 1.6/9.3 MB 11.1 MB/s eta 0:00:01
#      --------- ------------------------------ 2.1/9.3 MB 11.3 MB/s eta 0:00:01
#      ----------- ---------------------------- 2.7/9.3 MB 11.3 MB/s eta 0:00:01
#      ------------- -------------------------- 3.2/9.3 MB 11.4 MB/s eta 0:00:01
#      ---------------- ----------------------- 3.8/9.3 MB 11.5 MB/s eta 0:00:01
#      ------------------ --------------------- 4.3/9.3 MB 11.5 MB/s eta 0:00:01
#      --------------------- ------------------ 4.9/9.3 MB 11.5 MB/s eta 0:00:01
#      ----------------------- ---------------- 5.4/9.3 MB 11.6 MB/s eta 0:00:01
#      ------------------------- -------------- 5.9/9.3 MB 11.5 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data from the CSV file
df = pd.read_csv('superstore_sales.csv')

# Select relevant features for segmentation
features = df[['Sales', 'Quantity', 'Discount', 'Profit']]

# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Perform K-means clustering (for example, with 3 clusters)
num_clusters = 3
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df['Cluster'] = kmeans.fit_predict(scaled_features)

# Analyze the segments
segment_analysis = df.groupby('Cluster').agg({
    'Sales': 'mean',
    'Quantity': 'mean',
    'Discount': 'mean',
    'Profit': 'mean',
    'Customer ID': 'count'
}).reset_index()

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x='Cluster', y='Sales', data=segment_analysis, palette='viridis')
plt.xlabel('Cluster')
plt.ylabel('Average Sales')
plt.title('Average Sales by Cluster')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\user\AppData\Local\Temp\ipykernel_10604\1565088556.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Cluster', y='Sales', data=segment_analysis, palette='viridis')

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Load the data from the CSV file
df = pd.read_csv('superstore_sales.csv')

# Select relevant features for segmentation
features = df[['Sales', 'Quantity', 'Discount', 'Profit']]

# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Perform K-means clustering (for example, with 3 clusters)
num_clusters = 3
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df['CustomerSegment'] = kmeans.fit_predict(scaled_features)

# Analyze the segments
segment_analysis = df.groupby('CustomerSegment').agg({
    'Sales': 'mean',
    'Quantity': 'mean',
    'Discount': 'mean',
    'Profit': 'mean',
    'Customer ID': 'count'
}).reset_index()

# Print segment analysis
print(segment_analysis)
# Out:
#    CustomerSegment       Sales  Quantity  Discount      Profit  Customer ID
# 0                0  122.810078  2.835143  0.095300   20.658453         6909
# 1                1  158.884796  3.822097  0.661938 -106.792498         1068
# 2                2  634.118527  7.041646  0.097030  127.774992         2017
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Load the data from the CSV file
df = pd.read_csv('superstore_sales.csv')

# Select relevant features for segmentation
features = df[['Sales', 'Quantity', 'Discount', 'Profit']]

# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Perform K-means clustering (for example, with 3 clusters)
num_clusters = 3
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df['CustomerSegment'] = kmeans.fit_predict(scaled_features)

# Analyze the segments
segment_analysis = df.groupby('CustomerSegment').agg({
    'Sales': 'mean',
    'Quantity': 'mean',
    'Discount': 'mean',
    'Profit': 'mean',
    'Customer ID': 'count'
}).reset_index()

# Line chart for average sales across customer segments
plt.figure(figsize=(8, 6))
plt.plot(segment_analysis['CustomerSegment'], segment_analysis['Sales'], marker='o', color='b', label='Average Sales')
plt.xlabel('Customer Segment')
plt.ylabel('Average Sales')
plt.title('Average Sales Across Customer Segments')
plt.xticks(segment_analysis['CustomerSegment'])
plt.legend()
plt.grid(True)
plt.show()
# Print unique customer segments
print(df['CustomerSegment'].unique())
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [0 1 2]

# %%
# Calculate total sales for each product
top_products = df.groupby('Product Name')['Sales'].sum().reset_index()

# Sort products by total sales in descending order
top_products = top_products.sort_values(by='Sales', ascending=False).head(10)  # Select top 10 products

# Create a pie chart for the top-selling products
plt.figure(figsize=(8, 8))
plt.pie(top_products['Sales'], labels=top_products['Product Name'], autopct='%1.1f%%', startangle=140)
plt.title('Top 10 Selling Products')
plt.show()
